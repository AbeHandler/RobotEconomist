# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
def normalize_features(X_train, X_test):
    from sklearn.preprocessing import StandardScaler # import library 
    scaler = StandardScaler() # call an object function
    scaler.fit(X_train)   # calculate mean, std in X_train  (x-u)/s
    X_train_norm = scaler.transform(X_train)  # apply normalization on X_train
    X_test_norm = scaler.transform(X_test)    # apply normalization on X_test
    return X_train_norm, X_test_norm

# %%
#load concatenated data in csv format

data = pd.read_csv('Causal_Text.csv')

data.drop('Unnamed: 0', inplace=True, axis=1)
data.drop('Unnamed: 1', inplace=True, axis=1)
data.drop('Unnamed: 2', inplace=True, axis=1)
data.drop('Unnamed: 3', inplace=True, axis=1)
data.drop('Unnamed: 4', inplace=True, axis=1)
data.drop('Unnamed: 5', inplace=True, axis=1)
data.drop('Unnamed: 6', inplace=True, axis=1)

print(data.head())

X = data.Text
y = data.Contains_Relation
# Out:
#                                                 Text  Contains_Relation
# 0  "We find that callers experience three to six ...                  1
# 1  "Empirically, higher volatility of electricity...                  1
# 2  "I find that the mission, whether matched or r...                  1
# 3  "This suggests that superstitious belief still...                  1
# 4  "The change in the sampling level is indetermi...                  1

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(X) #create bag of words

X_train, X_test, y_train, y_test = train_test_split(X, y) #split data 

#X_train_norm, X_test_norm = normalize_features(X_train, X_test)

# %%
#summary of words in data

feature_names = vectorizer.get_feature_names()
print("Number of features: {}".format(len(feature_names)))
print("Last 15 Features: {}".format(feature_names[(2857-15):2857]))
vectorizer.vocabulary_
# Out:
# Number of features: 6338
# Last 15 Features: ['income', 'incoming', 'incompatible', 'incomplete', 'incongruent', 'inconsistencies', 'inconsistency', 'inconsistent', 'incorporated', 'incorporates', 'incorporating', 'incorporation', 'increase', 'increased', 'increases']
# /Users/seancottrell/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# {'we': 6066,
#  'find': 2330,
#  'that': 5630,
#  'callers': 891,
#  'experience': 2171,
#  'three': 5688,
#  'to': 5715,
#  'six': 5199,
#  'times': 5707,
#  'less': 3260,
#  'discomfort': 1721,
#  'per': 4127,
#  'unit': 5879,
#  'of': 3862,
#  'time': 5704,
#  'while': 6107,
#  'waiting': 6042,
#  'for': 2384,
#  'callbacks': 889,
#  'than': 5627,
#  'in': 2821,
#  'queue': 4537,
#  'suggesting': 5471,
#  'offering': 3869,
#  'can': 899,
#  'increase': 2854,
#  'service': 5086,
#  'quality': 4523,
#  'by': 870,
#  'channeling': 997,
#  'an': 410,
#  'alternative': 390,
#  'channel': 995,
#  'where': 6099,
#  'they': 5671,
#  'empirically': 1968,
#  'higher': 2671,
#  'volatility': 6028,
#  'electricity': 1942,
#  'prices': 4349,
#  'leads': 3236,
#  'cash': 939,
#  'holdings': 2698,
#  'and': 426,
#  'this': 5680,
#  'effect': 1917,
#  'is': 3100,
#  'robust': 4912,
#  'instrumenting': 2983,
#  'price': 4346,
#  'risk': 4898,
#  'using': 5936,
#  'weather': 6077,
#  'the': 5632,
#  'mission': 3571,
#  'whether': 6104,
#  'matched': 3448,
#  'or': 3953,
#  'random': 4565,
#  'increases': 2856,
#  'effort': 1929,
#  'compared': 1166,
#  'no': 3753,
#  'condition': 1233,
#  'suggests': 5475,
#  'superstitious': 5489,
#  'belief': 723,
#  'still': 5366,
#  'affects': 297,
#  'economic': 1896,
#  'activities': 235,
#  'change': 988,
#  'sampling': 4956,
#  'level': 3264,
#  'indeterminate': 2871,
#  'because': 701,
#  'increased': 2855,
#  'productivity': 4406,
#  'means': 3475,
#  'firms': 2341,
#  'have': 2635,
#  'incentives': 2830,
#  'equilibrium': 2059,
#  'goodwill': 2553,
#  'indirectly': 2884,
#  'reduces': 4668,
#  'marginal': 3425,
#  'thus': 5695,
#  'reducing': 4670,
#  'sample': 4954,
#  'findings': 2332,
#  'suggest': 5469,
#  'receiving': 4633,
#  'stress': 5393,
#  'related': 4715,
#  'medication': 3489,
#  'significantly': 5171,
#  'employees': 1972,
#  'at': 580,
#  'organizations': 3967,
#  'especially': 2074,
#  'those': 5682,
#  'undergo': 5848,
#  'broad': 833,
#  'simultaneous': 5186,
#  'changes': 990,
#  'along': 381,
#  'several': 5100,
#  'dimensions': 1695,
#  'such': 5462,
#  'campaigns': 898,
#  'often': 3885,
#  'take': 5547,
#  'form': 2402,
#  'charity': 1012,
#  'linked': 3296,
#  'promotions': 4443,
#  'whereby': 6101,
#  'firm': 2340,
#  'donates': 1822,
#  'specific': 5267,
#  'amount': 406,
#  'charitable': 1011,
#  'cause': 947,
#  'when': 6097,
#  'customer': 1479,
#  'takes': 5552,
#  'up': 5905,
#  'promotion': 4441,
#  'through': 5691,
#  'purchase': 4504,
#  'moderate': 3592,
#  'turbulence': 5809,
#  'value': 5954,
#  'flexibility': 2354,
#  'making': 3390,
#  'supplier': 5493,
#  'selection': 5042,
#  'more': 3629,
#  'difficult': 1684,
#  'commitment': 1145,
#  'mitigating': 3578,
#  'status': 5346,
#  'quo': 4544,
#  'bias': 752,
#  'integrated': 2993,
#  'structures': 5407,
#  'our': 3984,
#  'results': 4854,
#  'provide': 4473,
#  'field': 2310,
#  'based': 685,
#  'evidence': 2115,
#  'pfp': 4170,
#  'participative': 4072,
#  'goal': 2547,
#  'setting': 5094,
#  'affect': 294,
#  'accuracy': 217,
#  'goals': 2548,
#  'effects': 1923,
#  'are': 503,
#  'associated': 562,
#  'with': 6133,
#  'both': 804,
#  'information': 2929,
#  'exchange': 2141,
#  'managers': 3400,
#  'influence': 2921,
#  'study': 5412,
#  'how': 2727,
#  'monetary': 3611,
#  'policy': 4223,
#  'funding': 2474,
#  'composition': 1203,
#  'banking': 673,
#  'sector': 5020,
#  'paper': 4048,
#  'identifies': 2757,
#  'number': 3819,
#  'obstacles': 3844,
#  'international': 3037,
#  'generalizability': 2508,
#  'shows': 5158,
#  'technical': 5576,
#  'systems': 5537,
#  'research': 4809,
#  'social': 5225,
#  'different': 1677,
#  'ways': 6065,
#  'comparison': 1169,
#  'case': 937,
#  'there': 5660,
#  'learning': 3242,
#  'show': 5152,
#  'uncertainty': 5835,
#  'relatively': 4724,
#  'low': 3355,
#  'opts': 3952,
#  'product': 4403,
#  'inferior': 2914,
#  'design': 1615,
#  'accompanied': 203,
#  'lower': 3356,
#  'ii': 2767,
#  'high': 2670,
#  'chooses': 1031,
#  'superior': 5484,
#  'interestingly': 3024,
#  'ôs': 6279,
#  'expected': 2165,
#  'decreases': 1537,
#  'either': 1934,
#  'absolute': 190,
#  'sense': 5060,
#  'former': 2411,
#  'relative': 4723,
#  'latter': 3227,
#  'one': 3903,
#  'explanation': 2189,
#  'spending': 5283,
#  'may': 3467,
#  'lead': 3231,
#  'variety': 5975,
#  'which': 6106,
#  'tend': 5600,
#  'be': 697,
#  'overlooked': 4012,
#  'aggregate': 315,
#  'statistics': 5345,
#  'even': 2108,
#  'if': 2763,
#  'output': 3992,
#  'whereas': 6100,
#  'most': 3633,
#  'these': 5665,
#  'characteristics': 1002,
#  'predict': 4291,
#  'proxy': 4485,
#  'contests': 1313,
#  'series': 5079,
#  'prior': 4367,
#  'targets': 5562,
#  'also': 385,
#  'poor': 4232,
#  'stock': 5373,
#  'performance': 4138,
#  'investments': 3087,
#  'reserves': 4815,
#  'payouts': 4112,
#  'shareholders': 5112,
#  'management': 3397,
#  'entrenchment': 2036,
#  'instead': 2973,
#  'expanding': 2159,
#  'menu': 3500,
#  'choices': 1029,
#  'agent': 311,
#  'aware': 648,
#  'she': 5119,
#  'has': 2630,
#  'been': 710,
#  'denied': 1587,
#  'contract': 1325,
#  'valued': 5955,
#  'on': 3901,
#  'other': 3980,
#  'hand': 2614,
#  'long': 3336,
#  'production': 4404,
#  'runs': 4936,
#  'average': 640,
#  'makespan': 3389,
#  'completion': 1194,
#  'coils': 1101,
#  'natural': 3695,
#  'idea': 2749,
#  'should': 5151,
#  'intuitively': 3069,
#  'provider': 4475,
#  'profit': 4414,
#  'sell': 5047,
#  'idle': 2762,
#  'instances': 2969,
#  'secondary': 5014,
#  'market': 3431,
#  'example': 2131,
#  'via': 6001,
#  'preemptible': 4303,
#  'spot': 5300,
#  'contractually': 1332,
#  'specified': 5272,
#  'inevitably': 2905,
#  'conflicting': 1245,
#  'simultaneously': 5187,
#  'likelihood': 3281,
#  'welfare': 6091,
#  'improving': 2817,
#  'opportunistic': 3929,
#  'behavior': 718,
#  'experiment': 2176,
#  'loan': 3317,
#  'repayments': 4768,
#  'period': 4143,
#  'expectations': 2164,
#  'about': 184,
#  'response': 4833,
#  'shopbots': 5140,
#  'substantially': 5445,
#  'consumer': 1300,
#  'utility': 5941,
#  'searching': 5007,
#  'intelligently': 3000,
#  'then': 5648,
#  'selectively': 5044,
#  'presenting': 4324,
#  'offers': 3871,
#  'consequently': 1266,
#  'providers': 4476,
#  'improve': 2812,
#  'disappear': 1712,
#  'upcode': 5907,
#  'misreport': 3567,
#  'hais': 2609,
#  'possibly': 4254,
#  'unintentionally': 5877,
#  'manner': 3409,
#  'reimbursement': 4710,
#  'avoids': 646,
#  'financial': 2325,
#  'penalties': 4120,
#  'exploit': 2194,
#  'feature': 2293,
#  'structured': 5406,
#  'finance': 2324,
#  'rating': 4588,
#  'shopping': 5141,
#  'incumbent': 2862,
#  'ratings': 4589,
#  'it': 3109,
#  'extends': 2217,
#  'some': 5243,
#  'bellman': 726,
#  'work': 6145,
#  'transformed': 5765,
#  'states': 5336,
#  'successive': 5460,
#  'stages': 5318,
#  'not': 3803,
#  'properties': 4452,
#  'demanded': 1577,
#  'state': 5333,
#  'norm': 3795,
#  'need': 3707,
#  'diminish': 1696,
#  'all': 360,
#  'fact': 2252,
#  'particular': 4073,
#  'contrary': 1334,
#  'conventional': 1351,
#  'war': 6053,
#  'attrition': 613,
#  'benefits': 736,
#  'follower': 2378,
#  'generally': 2513,
#  'delays': 1564,
#  'first': 2343,
#  'move': 3645,
#  'rate': 4582,
#  'îwhich': 6273,
#  'tends': 5604,
#  'benefit': 735,
#  'îcan': 6240,
#  'hasten': 2632,
#  'investment': 3086,
#  'from': 2455,
#  'laboratory': 3203,
#  'studies': 5411,
#  'demonstrate': 1582,
#  'exposure': 2209,
#  'messages': 3511,
#  'praise': 4276,
#  'customers': 1480,
#  'good': 2551,
#  'deeds': 1540,
#  'subsequent': 5438,
#  'self': 5046,
#  'interested': 3022,
#  'indulgent': 2894,
#  'behaviors': 720,
#  'publicize': 4497,
#  'company': 1162,
#  'thank': 5629,
#  'consumers': 1301,
#  'their': 5642,
#  'patronage': 4099,
#  'furthermore': 2479,
#  'driven': 1848,
#  'operator': 3925,
#  'values': 5956,
#  'goods': 2552,
#  'decrease': 1535,
#  'quickly': 4541,
#  'expect': 2162,
#  'bundling': 853,
#  'suboptimal': 5427,
#  'government': 2558,
#  'revealing': 4868,
#  'losing': 3347,
#  'bids': 761,
#  'regret': 4700,
#  'sensitive': 5061,
#  'bidders': 759,
#  'anticipate': 454,
#  'bid': 757,
#  'conservatively': 1270,
#  'decreasing': 1538,
#  'revenue': 4871,
#  'single': 5189,
#  'problem': 4385,
#  'capacity': 909,
#  'does': 1809,
#  'optimal': 3939,
#  'but': 862,
#  'unimodal': 5875,
#  'nonconvex': 3766,
#  'cost': 1388,
#  'function': 2465,
#  'etf': 2094,
#  'activity': 236,
#  'short': 5143,
#  'run': 4934,
#  'informational': 2930,
#  'efficiency': 1926,
#  'stocks': 5376,
#  'weak': 6067,
#  'environments': 2047,
#  'model': 3587,
#  'predicts': 4300,
#  'sorting': 5249,
#  'under': 5845,
#  'asymmetric': 575,
#  'causes': 949,
#  'turn': 5810,
#  'away': 649,
#  'candidates': 902,
#  'would': 6163,
#  'efficient': 1927,
#  'pps': 4270,
#  'hiring': 2683,
#  'manager': 3398,
#  'outside': 3993,
#  'option': 3949,
#  'managerial': 3399,
#  'aversion': 642,
#  'becomes': 704,
#  'selective': 5043,
#  'as': 535,
#  'features': 2294,
#  'sponsorship': 5298,
#  'willingness': 6122,
#  'compete': 1176,
#  'among': 403,
#  'men': 3497,
#  'neither': 3724,
#  'channels': 998,
#  'women': 6141,
#  'manufacturers': 3416,
#  'do': 1804,
#  'sufficient': 5467,
#  'meet': 3492,
#  'demand': 1576,
#  'cannot': 903,
#  'determine': 1642,
#  'methods': 3517,
#  'allocate': 366,
#  'retailers': 4857,
#  'mskf': 3657,
#  'length': 3258,
#  'historical': 2685,
#  'data': 1495,
#  'increasing': 2857,
#  'forecasting': 2392,
#  'horizon': 2711,
#  'sensitivity': 5063,
#  'school': 4987,
#  'districts': 1783,
#  'cycle': 1484,
#  'each': 1876,
#  'job': 3135,
#  'processed': 4393,
#  'incurs': 2866,
#  'loss': 3348,
#  'linearly': 3292,
#  'its': 3117,
#  'úvery': 6335,
#  'search': 5004,
#  'levels': 3266,
#  'system': 5533,
#  'sum': 5478,
#  'manufacturer': 3415,
#  'retailer': 4856,
#  'profits': 4417,
#  'upon': 5914,
#  'centralization': 970,
#  'accommodating': 202,
#  'line': 3288,
#  'sitting': 5194,
#  'selling': 5050,
#  'priority': 4370,
#  'bring': 830,
#  'extra': 2227,
#  'although': 394,
#  'îselling': 6263,
#  'mainly': 3379,
#  'allowing': 376,
#  'practice': 4272,
#  'discrimination': 1741,
#  'extracts': 2232,
#  'surplus': 5506,
#  'so': 5223,
#  'expansion': 2161,
#  'attracting': 607,
#  'who': 6110,
#  'otherwise': 3983,
#  'join': 3141,
#  'computational': 1209,
#  'best': 743,
#  'frequency': 2445,
#  'direct': 1699,
#  'shipping': 5133,
#  'policies': 4222,
#  'used': 5928,
#  'obtain': 3845,
#  'worst': 6160,
#  'gives': 2540,
#  'percent': 4129,
#  'error': 2070,
#  'respect': 4828,
#  'bound': 807,
#  'routing': 4927,
#  'allowed': 375,
#  '44': 130,
#  'large': 3212,
#  'set': 5091,
#  'randomly': 4569,
#  'generated': 2516,
#  'consisting': 1283,
#  'automobile': 631,
#  'sales': 4946,
#  'transaction': 5760,
#  'major': 3384,
#  'automaker': 627,
#  'authors': 626,
#  '20': 68,
#  'improvement': 2814,
#  'prediction': 4295,
#  'over': 4001,
#  'art': 529,
#  'benchmark': 729,
#  'models': 3591,
#  'result': 4851,
#  '10': 8,
#  'revenues': 4872,
#  'optimizing': 3947,
#  'offer': 3867,
#  'counter': 1396,
#  'intuitive': 3068,
#  'examples': 2132,
#  'switchover': 5526,
#  'wip': 6131,
#  'reported': 4784,
#  'automation': 630,
#  'improves': 2816,
#  'clinical': 1072,
#  'admissions': 267,
#  'profitable': 4416,
#  'residents': 4817,
#  '14': 23,
#  'consistent': 1281,
#  'developed': 1651,
#  'theory': 5657,
#  'shifting': 5127,
#  'temporally': 5596,
#  'frequent': 2446,
#  'quota': 4545,
#  'structure': 5405,
#  'performing': 4141,
#  'salespeople': 4947,
#  'preventing': 4343,
#  'them': 5645,
#  'giving': 2541,
#  'later': 3224,
#  'periods': 4146,
#  'within': 6135,
#  'evaluation': 2105,
#  'commonly': 1151,
#  'held': 2651,
#  'úmatthew': 6315,
#  'dominates': 1819,
#  'îwider': 6274,
#  'distribution': 1781,
#  'rewards': 4884,
#  'overall': 4002,
#  'contest': 1310,
#  'patient': 4096,
#  'volume': 6029,
#  'hospital': 2715,
#  'reduced': 4667,
#  'costs': 1391,
#  'content': 1308,
#  'submission': 5423,
#  'engagement': 2004,
#  'retention': 4861,
#  'users': 5934,
#  'hazard': 2638,
#  'ending': 1984,
#  'session': 5090,
#  'approximately': 495,
#  '11': 13,
#  'baseline': 686,
#  'abandoning': 177,
#  'game': 2490,
#  'app': 464,
#  'orginally': 3971,
#  'budget': 841,
#  'allocating': 369,
#  'cuts': 1483,
#  'well': 6092,
#  'presented': 4323,
#  'finally': 2323,
#  'examine': 2127,
#  'procedures': 4390,
#  'degree': 1557,
#  'common': 1149,
#  'fewer': 2307,
#  'mutually': 3681,
#  'beneficial': 734,
#  'agreements': 327,
#  'attained': 591,
#  'supply': 5496,
#  'chain': 981,
#  'horizontal': 2713,
#  'merger': 3504,
#  'any': 458,
#  'tier': 5698,
#  'will': 6120,
#  'reduction': 4671,
#  'exceeds': 2134,
#  'certain': 976,
#  'threshold': 5690,
#  'larger': 3214,
#  'premerger': 4310,
#  'markup': 3440,
#  'experiments': 2181,
#  'little': 3309,
#  'gender': 2506,
#  'expression': 2211,
#  'minority': 3551,
#  'views': 6008,
#  'indicate': 2874,
#  'deteriorates': 1636,
#  'fill': 2316,
#  'requirement': 4800,
#  'companies': 1160,
#  'increasingly': 2858,
#  'personalizing': 4158,
#  'offerings': 3870,
#  'history': 2687,
#  'interactions': 3013,
#  'note': 3805,
#  'point': 4219,
#  'out': 3985,
#  'similar': 5172,
#  'formula': 2413,
#  'holds': 2699,
#  'requirements': 4801,
#  'global': 2542,
#  'semiconductor': 5053,
#  'industry': 2897,
#  'addition': 251,
#  'serving': 5089,
#  'mechanism': 3481,
#  'sourcing': 5254,
#  'knowledge': 3184,
#  'strong': 5399,
#  'internal': 3034,
#  'linkages': 3295,
#  'help': 2652,
#  'internalization': 3035,
#  'create': 1431,
#  'technological': 5579,
#  'interdependence': 3019,
#  'across': 228,
#  'locations': 3326,
#  'next': 3746,
#  'concave': 1216,
#  'similarly': 5174,
#  'resulting': 4853,
#  'borrowing': 803,
#  'employment': 1974,
#  'whose': 6113,
#  'effective': 1919,
#  'capital': 911,
#  'percentage': 4130,
#  'fixed': 2351,
#  'assets': 554,
#  'expenditures': 2169,
#  'feedback': 2300,
#  'bidder': 758,
#  'continuous': 1322,
#  'combinatorial': 1130,
#  'auctions': 616,
#  '811': 162,
#  'gediminas': 2505,
#  'adomavicius': 268,
#  'shawn': 5118,
#  'curley': 1466,
#  'alok': 379,
#  'gupta': 2601,
#  'pallab': 4045,
#  'sanyalrecent': 4957,
#  'theoretical': 5653,
#  'advances': 277,
#  'shown': 5155,
#  'îin': 6250,
#  'combinations': 1129,
#  'trade': 5749,
#  'complementarities': 1186,
#  'underestimation': 5847,
#  'stabilizes': 5312,
#  'negative': 3712,
#  'consequences': 1265,
#  'choosing': 1032,
#  'law': 3228,
#  'strategy': 5388,
#  'future': 2480,
#  'clearly': 1065,
#  'what': 6096,
#  'you': 6186,
#  'being': 721,
#  'advertisers': 286,
#  'use': 5927,
#  'online': 3906,
#  'target': 5560,
#  'marketing': 3433,
#  'effectiveness': 1922,
#  'despite': 1623,
#  'space': 5257,
#  'úconverse': 6296,
#  'functions': 2468,
#  'burden': 854,
#  'algorithm': 351,
#  'dramatic': 1840,
#  'arrivals': 525,
#  'potential': 4266,
#  'detainees': 1630,
#  'since': 5188,
#  '2003': 73,
#  '50': 137,
#  '000': 1,
#  'beds': 709,
#  'currently': 1468,
#  'required': 4799,
#  'estimation': 2089,
#  'arrival': 524,
#  'rates': 4584,
#  'very': 5999,
#  'due': 1862,
#  'uncertainties': 5834,
#  'direction': 1702,
#  'immigration': 2783,
#  'investigate': 3080,
#  'two': 5817,
#  'hypotheses': 2742,
#  'regarding': 4692,
#  'stimulus': 5369,
#  'preference': 4306,
#  'adoption': 272,
#  'cpoe': 1426,
#  'complexity': 1196,
#  'hospitals': 2716,
#  'corresponding': 1387,
#  'estimate': 2085,
#  'billion': 766,
#  'medicare': 3488,
#  'reimbursements': 4711,
#  'year': 6174,
#  'united': 5880,
#  'russia': 4939,
#  'preempt': 4302,
#  'countries': 1405,
#  'combined': 1132,
#  'coalitions': 1090,
#  'incentive': 2829,
#  'numerical': 3824,
#  'evaluations': 2106,
#  'range': 4570,
#  'important': 2804,
#  'caveats': 954,
#  'formulae': 2414,
#  'likely': 3282,
#  'acceptable': 196,
#  'practical': 4271,
#  'situations': 5197,
#  'infinite': 2916,
#  'situation': 5195,
#  'disclosure': 1720,
#  'sets': 5092,
#  'protected': 4467,
#  'given': 2538,
#  'vendor': 5985,
#  'release': 4729,
#  'patch': 4090,
#  'vulnerability': 6037,
#  'speed': 5279,
#  'develops': 1658,
#  'internet': 3038,
#  'changed': 989,
#  'however': 2728,
#  'magnitude': 3375,
#  'impact': 2784,
#  'therefore': 5663,
#  'tool': 5728,
#  'until': 5903,
#  'now': 3812,
#  'unknown': 5885,
#  'density': 1589,
#  'centers': 968,
#  'dcs': 1500,
#  'shortage': 5144,
#  'penalty': 4121,
#  'transportation': 5775,
#  'parameter': 4056,
#  'attenuation': 601,
#  'recipient': 4636,
#  'credibility': 1438,
#  'concerns': 1228,
#  'make': 3385,
#  'ex': 2121,
#  'ante': 452,
#  'forecasts': 2394,
#  'air': 336,
#  'travel': 5777,
#  '1963': 46,
#  '1968': 50,
#  'imply': 2801,
#  'econometric': 1892,
#  'accurate': 218,
#  'alternatives': 392,
#  'expert': 2182,
#  'judgment': 3154,
#  'extrapolation': 2233,
#  'superiority': 5485,
#  'span': 5258,
#  'forecast': 2388,
#  'inform': 2927,
#  'better': 747,
#  'labor': 3202,
#  'decisions': 1527,
#  'workload': 6151,
#  'banks': 675,
#  'operational': 3922,
#  'event': 2109,
#  'occurrence': 3855,
#  'allows': 377,
#  'platforms': 4208,
#  'ad': 244,
#  'intensity': 3006,
#  'blockers': 778,
#  'achieve': 219,
#  'returns': 4864,
#  'world': 6156,
#  'without': 6137,
#  'technology': 5582,
#  'ìenabled': 6224,
#  'formation': 2408,
#  'alliances': 365,
#  '207': 86,
#  'ali': 354,
#  'tafti': 5542,
#  'sunil': 5481,
#  'mithas': 3576,
#  'krishnanhow': 3192,
#  'success': 5456,
#  'joint': 3143,
#  'ventures': 5988,
#  'address': 254,
#  'endogeneity': 1985,
#  'instrumental': 2981,
#  'variable': 5966,
#  'analysis': 415,
#  'showing': 5154,
#  'innovation': 2949,
#  'after': 303,
#  'new': 3738,
#  'public': 4494,
#  'debt': 1513,
#  'seasoned': 5011,
#  'equity': 2062,
#  'bank': 672,
#  'loans': 3318,
#  'labels': 3201,
#  'remove': 4752,
#  'drm': 1852,
#  'entire': 2031,
#  'catalogue': 942,
#  'music': 3677,
#  'relaxing': 4727,
#  'album': 347,
#  'sharing': 5114,
#  'restrictions': 4846,
#  'initially': 2941,
#  'isp': 3104,
#  'drawn': 1845,
#  'eventually': 2112,
#  'spatial': 5259,
#  'competition': 1179,
#  'intense': 3002,
#  'logistics': 3334,
#  'positioned': 4246,
#  'closer': 1076,
#  'source': 5252,
#  'variability': 5965,
#  'downstream': 1835,
#  'upstream': 5917,
#  'locating': 3324,
#  'process': 4392,
#  'anywhere': 459,
#  'except': 2136,
#  'stage': 5317,
#  'same': 4953,
#  'theoretically': 5654,
#  'growth': 2586,
#  'idiosyncratic': 2761,
#  'shocks': 5137,
#  'positive': 4248,
#  'depending': 1596,
#  'moneyness': 3613,
#  'size': 5201,
#  'libraries': 3270,
#  'standard': 5322,
#  'declining': 1531,
#  'framework': 2438,
#  'initiatives': 2944,
#  'inventory': 3075,
#  'enhancing': 2017,
#  'measures': 3479,
#  'margins': 3428,
#  'directly': 1704,
#  'theories': 5655,
#  'introduction': 3065,
#  'fee': 2299,
#  'invariant': 3070,
#  'framing': 2439,
#  'difference': 1675,
#  'differences': 1676,
#  'test': 5620,
#  'reveals': 4869,
#  'gc': 2504,
#  'opinions': 3928,
#  'following': 2380,
#  'ruling': 4933,
#  'near': 3700,
#  'insolvent': 2960,
#  'delaware': 1560,
#  'altering': 388,
#  'tipping': 5713,
#  'itself': 3118,
#  'adversely': 283,
#  'satisfaction': 4958,
#  'repatronage': 4765,
#  'alter': 386,
#  'outcomes': 3987,
#  'detailed': 1629,
#  'indian': 2873,
#  'software': 5231,
#  'services': 5088,
#  'accumulation': 216,
#  'teams': 5575,
#  'get': 2531,
#  'reaching': 4601,
#  'regardless': 4693,
#  'week': 6081,
#  'bargaining': 679,
#  'position': 4245,
#  'weakens': 6068,
#  'only': 3907,
#  'final': 2322,
#  'month': 3625,
#  'greater': 2572,
#  'reliance': 4737,
#  'wholesale': 6111,
#  'argue': 509,
#  'resource': 4825,
#  'endowment': 1993,
#  'decision': 1525,
#  'makers': 3387,
#  'tolerance': 5723,
#  'resources': 4827,
#  ...}

# %%
#performance metrics 

LogReg = LogisticRegression()
LogReg.fit(X_train, y_train)

CV_scores = cross_val_score(LogReg, X_train, y_train, cv = 5)
print("Cross Validation Mean Score: {}".format(np.mean(CV_scores)))

print("Training Score: {}".format(LogReg.score(X_train, y_train)))
print("Testing Score: {}".format(LogReg.score(X_test, y_test)))
# Out:
# Cross Validation Mean Score: 0.9349189236760468
# Training Score: 0.9814077025232404
# Testing Score: 0.9284294234592445

# %%
#confusion matrix 

y_pred = LogReg.predict(X_test)
confusion = confusion_matrix(y_test, y_pred)

print("Confusion Matrix: {}".format(confusion))
# Out:
# Confusion Matrix: [[225  18]
#  [ 18 242]]

# %%
#Examine predicted probabilities vs class labels

probabilities = LogReg.predict_proba(X_test)

probabilities = np.delete(probabilities, 0, axis=1)

y_prob = []
for i in range(probabilities.shape[0]):
    y_prob.append(np.around(probabilities[i],2))
    
y_prob = np.array(y_prob).ravel()

MSE = np.mean((np.array(y_test) - np.array(y_prob))**2)
print("Mean Squared Error: {}".format(MSE))
# Out:
# Mean Squared Error: 0.05502425447316104
